# %%
# !i2cdetect -y 1

# %%
import mag
# import smbus2 as smbus
import numpy as np
import time
from collections import OrderedDict
# import RPi.GPIO as GPIO
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib notebook
# GPIO.setmode(GPIO.BCM)
# GPIO.setwarnings(False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8d48aeafabac> in <module>()
# ----> 1 import mag
#       2 import smbus2 as smbus
#       3 import numpy as np
#       4 import time
#       5 from collections import OrderedDict
#
# C:\Users\at8183jk\Desktop\Drive\Dropsync\School\Winona\Summer17\ROBhaT_Network\scripts\mag.py in <module>()
# ----> 1 import smbus2 as smbus
#       2 import time
#       3 import math
#       4 import numpy as np
#       5 from toolz.curried import map, filter, reduce, operator as op
#
# C:\Anaconda3\lib\site-packages\smbus2\__init__.py in <module>()
# ----> 1 from .smbus2 import SMBus, SMBusWrapper
#       2
#       3 __version__ = "0.1.4"
#
# C:\Anaconda3\lib\site-packages\smbus2\smbus2.py in <module>()
#      22
#      23 import os
# ---> 24 from fcntl import ioctl
#      25 from ctypes import c_uint32, c_uint8, c_uint16, POINTER, Structure, Array, Union
#      26
#
# ModuleNotFoundError: No module named 'fcntl'

# %%
# dir(GPIO)

# %%
GPIO.setup(4, GPIO.IN)

# %%
bus = smbus.SMBus(1)
address = 0x1e

sensor = mag.HMC5883L(bus, address, magDeclination=-0.171624)

# %%
data = mag.getTimedData(getMethod=sensor.getBearing, numSamples=500, pollRate=75)
data = np.array(data)

# %%
print(mag.textSummary(data, angular=True, radians=False))
# GPIO.cleanup()
# Out:
#     Data Summary
# ====================
# Mean:         78.969
# Min:          78.707
# Q1:           78.950
# Median:       78.953
# Q3:           79.070
# Max:          79.194
# IQR:           0.119
# STD:           0.091
# CircMean:     78.969
# CircSTD:       0.008
# ====================

# %%
plt.hist(data, bins=10, color='blue')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  17.,    0.,   47.,    0.,  178.,  113.,    0.,  135.,    0.,   10.]),
#  array([ 78.70721978,  78.7558564 ,  78.80449302,  78.85312964,
#          78.90176626,  78.95040288,  78.9990395 ,  79.04767612,
#          79.09631274,  79.14494936,  79.19358598]),
#  <a list of 10 Patch objects>)

# %%
data = np.rand(15)
